# %% [markdown]
# <a href="https://colab.research.google.com/github/seap-udea/fargopy/blob/main/fargopy_flux_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/juupitergeci/fargopy-dev.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
import fargopy as fp
from fargopy.Fsimulation import DataHandler
# %load_ext autoreload
# %autoreload 2
# Out:
# Running FARGOpy version 0.3.12

# %% [markdown]
# # FARGOpy
# ## Wrapping FRAGO3D

# %% [markdown]
# ## Interpolación en XYZ

# %% [markdown]
# La interpolación ahora se puede realizar en 3 dimensiones espaciales

# %%
# Cargamos los datos de la simulación

fp.Simulation.download_precomputed('p3disoj')
sim=fp.Simulation(output_dir='/tmp/p3disoj')

# Cambiar dir_path por la ruta donde tienen los outputs de Fargo3D
#sim = fp.Simulation(output_dir='')
# Out:
# Precomputed output directory '/tmp/p3disoj' already exist
# FARGO3D directory '/root/fargo3d/' does not exist.
# Now you are connected with output directory '/tmp/p3disoj'
# Found a variables.par file in '/tmp/p3disoj', loading properties
# Loading variables
# 85 variables loaded
# Simulation in 3 dimensions
# Loading domain in spherical coordinates:
# 	Variable phi: 128 [[0, np.float64(-3.117048960983623)], [-1, np.float64(3.117048960983623)]]
# 	Variable r: 64 [[0, np.float64(0.5078125)], [-1, np.float64(1.4921875)]]
# 	Variable theta: 32 [[0, np.float64(1.4231400767948967)], [-1, np.float64(1.5684525767948965)]]
# Number of snapshots in output directory: 11
# Configuration variables and domains load into the object. See e.g. <sim>.vars

# %%
# Creamos la instancia de la clase DataHandler
# y cargamos los datos de la simulación

data_handler = DataHandler(sim)
data_handler.load_data(

    # Definimos el snapshot inicial y el final sobre el que queremos trabajar
    snapi=1,
    snapf=10
);
# Out:
# Loading 3D data.

# %% [markdown]
# Ahora para interpolar en algun punto dentro del dominio:

# %%
# Interpolamos el campo de densidad"

# Definimos las coordenadas y el tiempo en el que queremos interpolar
time=0.54
x=1.0
y=-0.25
z=0.05

# Interpolamos el campo de densidad
density = data_handler.interpolate_field(time,x,y,z,field_name="gasdens")
print(f"La densidad en las coordenadas {(x,y,z)} en el tiempo:{time}\n es : {density*sim.URHO*1e3:.3e}[kg/m^3]")

# Interpolar el campo de velocidad
velx,vely,velz = data_handler.interpolate_velocity(time,x,y,z)
# Out:
# La densidad en las coordenadas (1.0, -0.25, 0.05) en el tiempo:0.54
#  es : 4.856e-07[kg/m^3]

# %% [markdown]
# # Cálculo del Flujo 3D

# %% [markdown]
# Primero,la clase flux.SphereTessellationnos permite crear la superficie de una esfera teselada de radio $r$ centrada en un punto arbitrario (x,y,z) dentro de nuestra simulación.La teselación se realiza con subdivisiones triangulares en un icosaedro.
#
# Una vez se tiene la superficie teselada bien definida con sus centros y areas calculamos el flujo como:

# %% [markdown]
# $$ dJ = \rho\  \vec{v} \cdot d\vec{s} $$
#
# Sumando sobre dJ tenemos el flujo total en un instante de tiempo

# %% [markdown]
# Ahora creamos el objeto analyzer desde FluxAnalyzer3D para calcular el flujo total en cada instante de tiempo de la simulación interpolada.

# %%
from fargopy.flux import FluxAnalyzer3D
from fargopy import flux
import fargopy as fp
from fargopy.Fsimulation import DataHandler
# %load_ext autoreload
# %autoreload 2


# Cambiar dir_path por la ruta donde se tienen los outputs de Fargo3D
output_dir = '/tmp/p3disoj' # Cambiar por la ruta donde se tienen los outputs de Fargo3D
sim = fp.Simulation()


# Creamos el objeto
analyzer = FluxAnalyzer3D(
    output_dir=output_dir, # Cambiar por la ruta donde se tienen los outputs de Fargo3D
    sphere_center=(1, 0, 0), # Centro de la esfera (centrada en el planeta)
    radius=0.08,    # Radio de la esfera
    subdivisions=6,     # Número de subdivisiones
    snapi=1,        # Snapshot inicial
    snapf=10       # Snapshot final
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# FARGO3D directory '/root/fargo3d/' does not exist.
# FARGO3D directory '/root/fargo3d/' does not exist.
# Now you are connected with output directory '/tmp/p3disoj'
# Found a variables.par file in '/tmp/p3disoj', loading properties
# Loading variables
# 85 variables loaded
# Simulation in 3 dimensions
# Loading domain in spherical coordinates:
# 	Variable phi: 128 [[0, np.float64(-3.117048960983623)], [-1, np.float64(3.117048960983623)]]
# 	Variable r: 64 [[0, np.float64(0.5078125)], [-1, np.float64(1.4921875)]]
# 	Variable theta: 32 [[0, np.float64(1.4231400767948967)], [-1, np.float64(1.5684525767948965)]]
# Number of snapshots in output directory: 11
# Configuration variables and domains load into the object. See e.g. <sim>.vars
# Loading 3D data.

# %% [markdown]
# Podemos visualizar la región seleccionada para calcular el flujo con `analyzer.planet_sphere()`:

# %%
analyzer.planet_sphere()

# %% [markdown]
# Interpolamos los campos de velocidad y densidad en los centros de las superficies con las que teselamos la esfera, esto se hace con el método `analyzer.interpolate(time_steps)`, definimos cuantas divisiones de tiempo queremos (resolución temporal)

# %%
analyzer.interpolate(time_steps=100);
# Out:
# Interpolating fields: 100%|██████████| 100/100 [03:09<00:00,  1.89s/it]

# %% [markdown]
# Calculamos el flujo

# %%
# Calcular flujos
analyzer.calculate_fluxes();

# %% [markdown]
# Graficamos los resultados:

# %%
analyzer.plot_fluxes()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b77a445a-4bd0-4c40-9d9b-c26551ad646e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b77a445a-4bd0-4c40-9d9b-c26551ad646e")) {                    Plotly.newPlot(                        "b77a445a-4bd0-4c40-9d9b-c26551ad646e",                        [{"line":{"color":"dodgerblue","width":2},"mode":"lines","name":"Flux","x":[0.0,0.010101010101010102,0.020202020202020204,0.030303030303030304,0.04040404040404041,0.05050505050505051,0.06060606060606061,0.07070707070707072,0.08080808080808081,0.09090909090909091,0.10101010101010102,0.11111111111111112,0.12121212121212122,0.13131313131313133,0.14141414141414144,0.15151515151515152,0.16161616161616163,0.17171717171717174,0.18181818181818182,0.19191919191919193,0.20202020202020204,0.21212121212121213,0.22222222222222224,0.23232323232323235,0.24242424242424243,0.25252525252525254,0.26262626262626265,0.27272727272727276,0.2828282828282829,0.29292929292929293,0.30303030303030304,0.31313131313131315,0.32323232323232326,0.33333333333333337,0.3434343434343435,0.3535353535353536,0.36363636363636365,0.37373737373737376,0.38383838383838387,0.393939393939394,0.4040404040404041,0.4141414141414142,0.42424242424242425,0.43434343434343436,0.4444444444444445,0.4545454545454546,0.4646464646464647,0.4747474747474748,0.48484848484848486,0.494949494949495,0.5050505050505051,0.5151515151515152,0.5252525252525253,0.5353535353535354,0.5454545454545455,0.5555555555555556,0.5656565656565657,0.5757575757575758,0.5858585858585859,0.595959595959596,0.6060606060606061,0.6161616161616162,0.6262626262626263,0.6363636363636365,0.6464646464646465,0.6565656565656566,0.6666666666666667,0.6767676767676768,0.686868686868687,0.696969696969697,0.7070707070707072,0.7171717171717172,0.7272727272727273,0.7373737373737375,0.7474747474747475,0.7575757575757577,0.7676767676767677,0.7777777777777778,0.787878787878788,0.797979797979798,0.8080808080808082,0.8181818181818182,0.8282828282828284,0.8383838383838385,0.8484848484848485,0.8585858585858587,0.8686868686868687,0.8787878787878789,0.888888888888889,0.8989898989898991,0.9090909090909092,0.9191919191919192,0.9292929292929294,0.9393939393939394,0.9494949494949496,0.9595959595959597,0.9696969696969697,0.9797979797979799,0.98989898989899,1.0],"y":[6.796515250318839e-6,6.022920890965629e-6,5.25814160914222e-6,4.502177404848599e-6,3.755028278084747e-6,3.0166942288506782e-6,2.287175257146378e-6,1.5664713629718575e-6,8.545825463270992e-7,1.5150880721215888e-7,-5.427498543730183e-7,-1.2281934384284253e-6,-1.2037986759052554e-6,-1.181353558874024e-6,-1.160858087334737e-6,-1.1423122612873834e-6,-1.1257160807319794e-6,-1.1110695456684898e-6,-1.0983726560969606e-6,-1.0876254120173778e-6,-1.078827813429706e-6,-1.0719798603339996e-6,-1.0670815527302041e-6,-9.926688901804837e-7,-9.199437297522383e-7,-8.489060714454932e-7,-7.795559152601996e-7,-7.118932611964342e-7,-6.459181092541015e-7,-5.816304594333078e-7,-5.190303117339464e-7,-4.581176661560844e-7,-3.988925226997266e-7,-3.413548813648347e-7,-7.091385905432381e-8,1.974623090107776e-7,4.637736228303804e-7,7.280200824045379e-7,9.902016877332524e-7,1.2503184388165458e-6,1.5083703356543458e-6,1.7643573782467324e-6,2.0182795665936536e-6,2.2701369006951376e-6,2.519929380551144e-6,2.642707410997889e-6,2.765455405172824e-6,2.8881733630759778e-6,3.0108612847073297e-6,3.1335191700668894e-6,3.256147019154651e-6,3.3787448319706058e-6,3.501312608514751e-6,3.62385034878711e-6,3.7463580527876624e-6,3.8688357205164446e-6,3.907404283155343e-6,3.9483288105495415e-6,3.9916093026990445e-6,4.037245759603881e-6,4.085238181263996e-6,4.1355865676794135e-6,4.1882909188501454e-6,4.243351234776214e-6,4.300767515457557e-6,4.360539760894211e-6,4.4226679710861805 ...

# %% [markdown]
# ## Tasa de Acreción 3D
#
# Para calcular la tasa de acreción utilizamos el método `analyzer.calculate_accretion()`, este nos devuelve la tasa de acreción en cada instante de tiempo y la masa total acretada durante la simulación:
#
# Esta se calucula como:
#
# $$ \dot{M} = \frac{d}{dt}\int_{V}{\rho\ dV} $$
#
#
# Lo diferenciales de Volumen se definen a partir de la teselación, cada division de la superficie de la esfera es la base $ds$ de un tetraedro de altura $h=r$ con $r$ el radio de la esfera, este dV es entonces:  $dV=1/3 \cdot ds \cdot r$
#
#
# Luego la masa total acretada se calcula como:
#
#
# $$ M = \int \dot M \cdot dt$$

# %%
import plotly.graph_objects as go
import numpy as np

# Calcular la tasa de acreción y la masa total
accretion_rate, total_mass = analyzer.calculate_accretion()

# Calcular el promedio de la tasa de acreción
avg_accretion_rate = np.mean(accretion_rate)


# Creamos el gráfico con plotly
fig = go.Figure()

# Agregar la línea de la tasa de acreción
fig.add_trace(go.Scatter(
    x=analyzer.time,
    y=accretion_rate,
    mode='lines',
    name='Accretion Rate',
    line=dict(color='dodgerblue', width=2)
))

# Agregar la línea promedio
fig.add_trace(go.Scatter(
    x=analyzer.time,
    y=[avg_accretion_rate] * len(analyzer.time),
    mode='lines',
    name=f'Avg: {avg_accretion_rate:.2e} Msun/yr',
    line=dict(color='orangered', width=2, dash='dash')
))

# Configurar el diseño del gráfico
fig.update_layout(
    title="Accretion Rate Over Time",
    xaxis_title="Normalized Time",
    yaxis_title="Accretion Rate [Msun/yr]",
    template="plotly_white",
    font=dict(size=14),
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True, exponentformat="e"),
)

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="848e6d14-d60c-4770-87c9-e3fcfd015949" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("848e6d14-d60c-4770-87c9-e3fcfd015949")) {                    Plotly.newPlot(                        "848e6d14-d60c-4770-87c9-e3fcfd015949",                        [{"line":{"color":"dodgerblue","width":2},"mode":"lines","name":"Accretion Rate","x":[0.0,0.010101010101010102,0.020202020202020204,0.030303030303030304,0.04040404040404041,0.05050505050505051,0.06060606060606061,0.07070707070707072,0.08080808080808081,0.09090909090909091,0.10101010101010102,0.11111111111111112,0.12121212121212122,0.13131313131313133,0.14141414141414144,0.15151515151515152,0.16161616161616163,0.17171717171717174,0.18181818181818182,0.19191919191919193,0.20202020202020204,0.21212121212121213,0.22222222222222224,0.23232323232323235,0.24242424242424243,0.25252525252525254,0.26262626262626265,0.27272727272727276,0.2828282828282829,0.29292929292929293,0.30303030303030304,0.31313131313131315,0.32323232323232326,0.33333333333333337,0.3434343434343435,0.3535353535353536,0.36363636363636365,0.37373737373737376,0.38383838383838387,0.393939393939394,0.4040404040404041,0.4141414141414142,0.42424242424242425,0.43434343434343436,0.4444444444444445,0.4545454545454546,0.4646464646464647,0.4747474747474748,0.48484848484848486,0.494949494949495,0.5050505050505051,0.5151515151515152,0.5252525252525253,0.5353535353535354,0.5454545454545455,0.5555555555555556,0.5656565656565657,0.5757575757575758,0.5858585858585859,0.595959595959596,0.6060606060606061,0.6161616161616162,0.6262626262626263,0.6363636363636365,0.6464646464646465,0.6565656565656566,0.6666666666666667,0.6767676767676768,0.686868686868687,0.696969696969697,0.7070707070707072,0.7171717171717172,0.7272727272727273,0.7373737373737375,0.7474747474747475,0.7575757575757577,0.7676767676767677,0.7777777777777778,0.787878787878788,0.797979797979798,0.8080808080808082,0.8181818181818182,0.8282828282828284,0.8383838383838385,0.8484848484848485,0.8585858585858587,0.8686868686868687,0.8787878787878789,0.888888888888889,0.8989898989898991,0.9090909090909092,0.9191919191919192,0.9292929292929294,0.9393939393939394,0.9494949494949496,0.9595959595959597,0.9696969696969697,0.9797979797979799,0.98989898989899,1.0],"y":[-0.0003845239846248763,-0.0003845239846248791,-0.00038452398462488174,-0.0003845239846248844,-0.00038452398462488174,-0.0003845239846248763,-0.0003845239846248791,-0.00038452398462488174,-0.00038452398462488174,-0.00038452398462488174,-0.0003845239846248791,-0.00017258621351911677,0.00003935155758664819,0.00003935155758665087,0.00003935155758664819,0.00003935155758664819,0.00003935155758665087,0.00003935155758665087,0.00003935155758664819,0.00003935155758664819,0.0000393515575866455,0.00003935155758664819,0.00004288613229108987,0.00004642070699552886,0.00004642070699553154,0.00004642070699552886,0.00004642070699552617,0.00004642070699552886,0.00004642070699553154,0.00004642070699552886,0.00004642070699552886,0.00004642070699553154,0.00004642070699552886,-0.00012614503173385825,-0.0002987107704632373,-0.0002987107704632319,-0.0002987107704632373,-0.00029871077046323997,-0.00029871077046323454,-0.00029871077046323454,-0.0002987107704632373,-0.0002987107704632373,-0.0002987107704632373,-0.0002987107704632373,-0.0003463077710725793,-0.00039390477168192137,-0.00039390477168192137,-0.0003939047716819187,-0.00039390477168192137,-0.000393904771681924,-0.00039390477168192137,-0.00039390477168192137,-0.00039390477168192137,-0.00039390477168192137,-0.00039390477168192137,-0.00037770877766730326,-0.0003615127836526851,-0.00036151278365268244,-0.00036151278365268244,-0.00036151278365268244,-0.0003615127836526811,-0.000361512783652682 ...

# %%
print(f"Total Accreted Mass: {total_mass:.2e} Msun")
# Out:
# Total Accreted Mass: -3.02e-05 Msun

# %% [markdown]
# # Cálculo del Flujo en 2D

# %% [markdown]
# En el caso que quisieramos calcular sobre los planos XY o YZ de la simulación (La simulación puede estár en esféricas, fargopy se encarga de pasarla a cartesianas) Se utiliza la clase `FluxAnalyzer2D`
#
# En este caso se calcula el flujo a travez de un perímetro $l$, en este caso circular, se realiza dividiendo una circunferencia en sectores circulares de radio $r$ de n `subdivisión` centrado en la región que queremos calcular el flujo, este se calcula como:
#
# $$ dJ = \rho\  \vec{v} \cdot d\vec{l} $$
#
# Sumando sobre dJ tenemos el flujo total en un instante de tiempo

# %% [markdown]
# ## Plano XY ----> $\theta=1.56$ [rad]

# %%
import fargopy as fp
from fargopy.Fsimulation import DataHandler
from fargopy.flux import FluxAnalyzer2D
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Creamos el objeto
analyzer = FluxAnalyzer2D(
    output_dir='/tmp/p3disoj', # Cambiar por la ruta donde se tienen los outputs de Fargo3D
    plane="XY",        # Definimos el plano en el que queremos trabajar
    angle="theta=1.56", # Definimos el ángulo en el que queremos trabajar
    snapi=1,    # Snapshot inicial
    snapf=10,   # Snapshot final
    center=(1.0,0.0), # Centro de la circunferencia(centrada en el planeta)
    radius=0.1,  # Radio de la circunferencia
    subdivisions=100 # Número de subdivisiones
)
# Out:
# FARGO3D directory '/root/fargo3d/' does not exist.
# Now you are connected with output directory '/tmp/p3disoj'
# Found a variables.par file in '/tmp/p3disoj', loading properties
# Loading variables
# 85 variables loaded
# Simulation in 3 dimensions
# Loading domain in spherical coordinates:
# 	Variable phi: 128 [[0, np.float64(-3.117048960983623)], [-1, np.float64(3.117048960983623)]]
# 	Variable r: 64 [[0, np.float64(0.5078125)], [-1, np.float64(1.4921875)]]
# 	Variable theta: 32 [[0, np.float64(1.4231400767948967)], [-1, np.float64(1.5684525767948965)]]
# Number of snapshots in output directory: 11
# Configuration variables and domains load into the object. See e.g. <sim>.vars
# Loading 2D data for plane XY at angle theta=1.56 rad.

# %% [markdown]
# Visualizamos la Región sobre la que calcularemos el flujo

# %%
# Visualizar la región con la densidad de fondo
analyzer.plot_region()

# %% [markdown]
# Hallamos el valor del campo de densidad y velocidad en el centro de cada lado del polígono:
#
#
# - `analyzer.interpolate(time_steps=100)[0]` devuelve los valores del campo de velocidad
# - `analyzer.interpolate(time_steps=100)[1]` devuelve los valores del campo de densidad

# %%
analyzer.interpolate(time_steps=100);
# Out:
# Interpolating fields: 100%|██████████| 100/100 [02:52<00:00,  1.72s/it]

# %% [markdown]
# Calculamos el flujo:

# %%
analyzer.calculate_fluxes();

# %% [markdown]
# Visualizamos el flujo a travéz del tiempo

# %%
analyzer.plot_fluxes()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="32ba7ee2-371b-4340-ad09-0588dacdf595" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32ba7ee2-371b-4340-ad09-0588dacdf595")) {                    Plotly.newPlot(                        "32ba7ee2-371b-4340-ad09-0588dacdf595",                        [{"line":{"color":"dodgerblue","width":2},"mode":"lines","name":"Flux","x":[0.0,0.010101010101010102,0.020202020202020204,0.030303030303030304,0.04040404040404041,0.05050505050505051,0.06060606060606061,0.07070707070707072,0.08080808080808081,0.09090909090909091,0.10101010101010102,0.11111111111111112,0.12121212121212122,0.13131313131313133,0.14141414141414144,0.15151515151515152,0.16161616161616163,0.17171717171717174,0.18181818181818182,0.19191919191919193,0.20202020202020204,0.21212121212121213,0.22222222222222224,0.23232323232323235,0.24242424242424243,0.25252525252525254,0.26262626262626265,0.27272727272727276,0.2828282828282829,0.29292929292929293,0.30303030303030304,0.31313131313131315,0.32323232323232326,0.33333333333333337,0.3434343434343435,0.3535353535353536,0.36363636363636365,0.37373737373737376,0.38383838383838387,0.393939393939394,0.4040404040404041,0.4141414141414142,0.42424242424242425,0.43434343434343436,0.4444444444444445,0.4545454545454546,0.4646464646464647,0.4747474747474748,0.48484848484848486,0.494949494949495,0.5050505050505051,0.5151515151515152,0.5252525252525253,0.5353535353535354,0.5454545454545455,0.5555555555555556,0.5656565656565657,0.5757575757575758,0.5858585858585859,0.595959595959596,0.6060606060606061,0.6161616161616162,0.6262626262626263,0.6363636363636365,0.6464646464646465,0.6565656565656566,0.6666666666666667,0.6767676767676768,0.686868686868687,0.696969696969697,0.7070707070707072,0.7171717171717172,0.7272727272727273,0.7373737373737375,0.7474747474747475,0.7575757575757577,0.7676767676767677,0.7777777777777778,0.787878787878788,0.797979797979798,0.8080808080808082,0.8181818181818182,0.8282828282828284,0.8383838383838385,0.8484848484848485,0.8585858585858587,0.8686868686868687,0.8787878787878789,0.888888888888889,0.8989898989898991,0.9090909090909092,0.9191919191919192,0.9292929292929294,0.9393939393939394,0.9494949494949496,0.9595959595959597,0.9696969696969697,0.9797979797979799,0.98989898989899,1.0],"y":[0.001345045189908901,0.0013306213466277425,0.0013162006252709487,0.00130178302583852,0.0012873685483304547,0.0012729571927467549,0.0012585489590874193,0.0012441438473524483,0.001229741857541842,0.0012153429896555998,0.0012009472436937223,0.0011865546196562092,0.0011864159702025387,0.0011862418505973896,0.0011860322608407605,0.0011857872009326522,0.0011855066708730646,0.0011851906706619975,0.001184839200299451,0.0011844522597854253,0.00118402984911992,0.001183571968302936,0.001183078617334472,0.0011871608125407216,0.0011911007951959309,0.0011948985653000997,0.0011985541228532281,0.0012020674678553157,0.0012054386003063635,0.001208667520206371,0.0012117542275553374,0.0012146987223532644,0.0012175010046001507,0.0012201610742959964,0.0012095147943097203,0.0011987769081582432,0.0011879474158415658,0.0011770263173596876,0.0011660136127126075,0.0011549093019003276,0.0011437133849228468,0.0011324258617801649,0.0011210467324722824,0.0011095759969991991,0.0010980136553609147,0.0010821228781308576,0.001066239334881211,0.0010503630256119738,0.0010344939503231473,0.00101863210901473,0.0010027775016867237,0.0009869301283391269,0.0009710899889719403,0.0009552570835851642,0.0009394314121787978,0.0009236129747528424,0.0009069878464592867,0.0008905092818467846,0.0008741772809153364,0.0008579918436649415,0.0008419529700956001,0.0008260606602073122,0.0008103149140000784,0.0007947157314738974,0.0007792631126287704,0.0007639570574646965,0.0007487975659 ...

# %% [markdown]
# ## Tasa de Acreción 2D
#
# Para calcular la tasa de acreción utilizamos el método `analyzer.calculate_accretion()`, este nos devuelve la tasa de acreción en cada instante de tiempo y la masa total acretada durante la simulación:
#
# Esta se calucula como:
#
# $$ \dot{M} = \frac{d}{dt}\int_{s}{\rho\ ds} $$
#
# En este caso el $ds$ corresponde al area de cada sector circular en el que se dividió la circunferencia.
#
#
# Luego la masa total acretada se calcula como:
#
#
# $$ M = \int \dot M \cdot dt$$

# %%
# Calculate accretion rate and total accreted mass
accretion_rate, total_mass = analyzer.calculate_accretion()

# %%
import plotly.graph_objects as go
import numpy as np

# Calcular el promedio de la tasa de acreción
avg_accretion_rate = np.mean(accretion_rate)



# Crear la figura con Plotly
fig = go.Figure()

# Agregar la línea de la tasa de acreción
fig.add_trace(go.Scatter(
    x=analyzer.time,
    y=accretion_rate,
    mode='lines',
    name='Accretion Rate',
    line=dict(color='dodgerblue', width=2)
))

# Agregar la línea promedio
fig.add_trace(go.Scatter(
    x=analyzer.time,
    y=[avg_accretion_rate] * len(analyzer.time),
    mode='lines',
    name=f'Avg: {avg_accretion_rate:.2e} Msun/yr',
    line=dict(color='orangered', width=2, dash='dash')
))


fig.update_layout(
    title="Accretion Rate Over Time",
    xaxis_title="Normalized Time",
    yaxis_title="Accretion Rate [Msun/yr]",
    template="plotly_white",
    font=dict(size=14),
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True, exponentformat="e"),
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3de75dbc-7885-4f13-948a-efdcc2fc3120" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3de75dbc-7885-4f13-948a-efdcc2fc3120")) {                    Plotly.newPlot(                        "3de75dbc-7885-4f13-948a-efdcc2fc3120",                        [{"line":{"color":"dodgerblue","width":2},"mode":"lines","name":"Accretion Rate","x":[0.0,0.010101010101010102,0.020202020202020204,0.030303030303030304,0.04040404040404041,0.05050505050505051,0.06060606060606061,0.07070707070707072,0.08080808080808081,0.09090909090909091,0.10101010101010102,0.11111111111111112,0.12121212121212122,0.13131313131313133,0.14141414141414144,0.15151515151515152,0.16161616161616163,0.17171717171717174,0.18181818181818182,0.19191919191919193,0.20202020202020204,0.21212121212121213,0.22222222222222224,0.23232323232323235,0.24242424242424243,0.25252525252525254,0.26262626262626265,0.27272727272727276,0.2828282828282829,0.29292929292929293,0.30303030303030304,0.31313131313131315,0.32323232323232326,0.33333333333333337,0.3434343434343435,0.3535353535353536,0.36363636363636365,0.37373737373737376,0.38383838383838387,0.393939393939394,0.4040404040404041,0.4141414141414142,0.42424242424242425,0.43434343434343436,0.4444444444444445,0.4545454545454546,0.4646464646464647,0.4747474747474748,0.48484848484848486,0.494949494949495,0.5050505050505051,0.5151515151515152,0.5252525252525253,0.5353535353535354,0.5454545454545455,0.5555555555555556,0.5656565656565657,0.5757575757575758,0.5858585858585859,0.595959595959596,0.6060606060606061,0.6161616161616162,0.6262626262626263,0.6363636363636365,0.6464646464646465,0.6565656565656566,0.6666666666666667,0.6767676767676768,0.686868686868687,0.696969696969697,0.7070707070707072,0.7171717171717172,0.7272727272727273,0.7373737373737375,0.7474747474747475,0.7575757575757577,0.7676767676767677,0.7777777777777778,0.787878787878788,0.797979797979798,0.8080808080808082,0.8181818181818182,0.8282828282828284,0.8383838383838385,0.8484848484848485,0.8585858585858587,0.8686868686868687,0.8787878787878789,0.888888888888889,0.8989898989898991,0.9090909090909092,0.9191919191919192,0.9292929292929294,0.9393939393939394,0.9494949494949496,0.9595959595959597,0.9696969696969697,0.9797979797979799,0.98989898989899,1.0],"y":[-0.00030921605686422965,-0.00030921605686420813,-0.0003092160568641974,-0.00030921605686420813,-0.0003092160568641974,-0.0003092160568641974,-0.00030921605686420813,-0.00030921605686420813,-0.00030921605686420813,-0.0003092160568642027,-0.0003092160568642027,-0.000038615971149265235,0.00023198411456567763,0.00023198411456568302,0.00023198411456569373,0.00023198411456567763,0.00023198411456566687,0.0002319841145656884,0.00023198411456567763,0.00023198411456567763,0.00023198411456567763,0.00023198411456565616,0.00007790444010987441,-0.00007617523434592882,-0.00007617523434595031,-0.00007617523434593957,-0.00007617523434595031,-0.00007617523434595031,-0.00007617523434593957,-0.00007617523434595031,-0.00007617523434593957,-0.00007617523434593957,-0.00007617523434595031,-0.0006017898532934937,-0.0011274044722410425,-0.0011274044722410263,-0.0011274044722410263,-0.0011274044722410477,-0.0011274044722410371,-0.0011274044722410263,-0.0011274044722410263,-0.0011274044722410263,-0.0011274044722410371,-0.0011274044722410425,-0.001111321502314136,-0.0010952385323872405,-0.0010952385323872297,-0.001095238532387219,-0.0010952385323872405,-0.001095238532387235,-0.001095238532387235,-0.0010952385323872405,-0.0010952385323872297,-0.0010952385323872297,-0.0010952385323872243,-0.0009628240019838493,-0.0008304094715804692,-0.0008304094715804636,-0.0008304094715804692,-0.0008304094715804636,-0.000830409471580453,-0.0008304094715804583,-0.000 ...

# %%
print(f"Total Accreted Mass: {total_mass:.2e} Msun")
# Out:
# Total Accreted Mass: -7.38e-05 Msun

# %% [markdown]
# ## Plano XZ----> $\phi=0$

# %%
# Crear una instancia de FluxAnalyzer2D
analyzer = FluxAnalyzer2D(
    output_dir='/tmp/p3disoj', # Cambiar por la ruta donde se tienen los outputs de Fargo3D
    plane="XZ", # Definimos el plano en el que queremos trabajar
    angle="phi=0", # Definimos el ángulo en el que queremos trabajar
    snapi=1, # Snapshot inicial
    snapf=10, # Snapshot final
    center=(1.0,0.0), # Centro de la circunferencia(centrada en el planeta)
    radius=0.1, # Radio de la circunferencia
    subdivisions=100 # Número de subdivisiones
)
# Out:
# FARGO3D directory '/root/fargo3d/' does not exist.
# Now you are connected with output directory '/tmp/p3disoj'
# Found a variables.par file in '/tmp/p3disoj', loading properties
# Loading variables
# 85 variables loaded
# Simulation in 3 dimensions
# Loading domain in spherical coordinates:
# 	Variable phi: 128 [[0, np.float64(-3.117048960983623)], [-1, np.float64(3.117048960983623)]]
# 	Variable r: 64 [[0, np.float64(0.5078125)], [-1, np.float64(1.4921875)]]
# 	Variable theta: 32 [[0, np.float64(1.4231400767948967)], [-1, np.float64(1.5684525767948965)]]
# Number of snapshots in output directory: 11
# Configuration variables and domains load into the object. See e.g. <sim>.vars
# Loading 2D data for plane XZ at angle phi=0 rad.

# %%
# Visualizar la región con la densidad de fondo y la circunferencia
analyzer.plot_region()

# %%
# Interpolar los campos
analyzer.interpolate(time_steps=100);
# Out:
# Interpolating fields: 100%|██████████| 100/100 [00:31<00:00,  3.13it/s]

# %%
# Calculamos el flujo de masa y graficamos
analyzer.calculate_fluxes();
analyzer.plot_fluxes()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2fde108e-8e1f-45f0-9135-5fd66e477e42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fde108e-8e1f-45f0-9135-5fd66e477e42")) {                    Plotly.newPlot(                        "2fde108e-8e1f-45f0-9135-5fd66e477e42",                        [{"line":{"color":"dodgerblue","width":2},"mode":"lines","name":"Flux","x":[0.0,0.010101010101010102,0.020202020202020204,0.030303030303030304,0.04040404040404041,0.05050505050505051,0.06060606060606061,0.07070707070707072,0.08080808080808081,0.09090909090909091,0.10101010101010102,0.11111111111111112,0.12121212121212122,0.13131313131313133,0.14141414141414144,0.15151515151515152,0.16161616161616163,0.17171717171717174,0.18181818181818182,0.19191919191919193,0.20202020202020204,0.21212121212121213,0.22222222222222224,0.23232323232323235,0.24242424242424243,0.25252525252525254,0.26262626262626265,0.27272727272727276,0.2828282828282829,0.29292929292929293,0.30303030303030304,0.31313131313131315,0.32323232323232326,0.33333333333333337,0.3434343434343435,0.3535353535353536,0.36363636363636365,0.37373737373737376,0.38383838383838387,0.393939393939394,0.4040404040404041,0.4141414141414142,0.42424242424242425,0.43434343434343436,0.4444444444444445,0.4545454545454546,0.4646464646464647,0.4747474747474748,0.48484848484848486,0.494949494949495,0.5050505050505051,0.5151515151515152,0.5252525252525253,0.5353535353535354,0.5454545454545455,0.5555555555555556,0.5656565656565657,0.5757575757575758,0.5858585858585859,0.595959595959596,0.6060606060606061,0.6161616161616162,0.6262626262626263,0.6363636363636365,0.6464646464646465,0.6565656565656566,0.6666666666666667,0.6767676767676768,0.686868686868687,0.696969696969697,0.7070707070707072,0.7171717171717172,0.7272727272727273,0.7373737373737375,0.7474747474747475,0.7575757575757577,0.7676767676767677,0.7777777777777778,0.787878787878788,0.797979797979798,0.8080808080808082,0.8181818181818182,0.8282828282828284,0.8383838383838385,0.8484848484848485,0.8585858585858587,0.8686868686868687,0.8787878787878789,0.888888888888889,0.8989898989898991,0.9090909090909092,0.9191919191919192,0.9292929292929294,0.9393939393939394,0.9494949494949496,0.9595959595959597,0.9696969696969697,0.9797979797979799,0.98989898989899,1.0],"y":[-0.000021164426684383836,-0.000023393773506157855,-0.000025579964959772806,-0.000027723001045228752,-0.000029822881762525632,-0.00003187960711166347,-0.000033893177092642256,-0.00003586359170546204,-0.000037790850950122746,-0.00003967495482662441,-0.000041515903334967034,-0.000043313696475150614,-0.0000446337976040259,-0.00004595776182214299,-0.00004728558912950188,-0.00004861727952610256,-0.000049952833011945066,-0.000051292249587029364,-0.00005263552925135549,-0.0000539826720049234,-0.000055333677847733144,-0.000056688546779784634,-0.00005804727880107797,-0.00005678815342536458,-0.000055553625614297693,-0.00005434369536787727,-0.00005315836268610332,-0.00005199762756897583,-0.00005086149001649484,-0.000049749950028660315,-0.000048663007605472274,-0.0000476006627469307,-0.00004656291545303556,-0.00004554976572378692,-0.000043662667006112604,-0.00004180849122105438,-0.00003998723836861234,-0.00003819890844878635,-0.00003644350146157648,-0.000034721017406982765,-0.00003303145628500511,-0.0000313748180956436,-0.00002975110283889822,-0.000028160310514768945,-0.00002660244112325579,-0.00002659490827553008,-0.00002658562515855274,-0.00002657459177232373,-0.00002656180811684307,-0.000026547274192110763,-0.000026530989998126814,-0.00002651295553489121,-0.000026493170802403944,-0.000026471635800665054,-0.000026448350529674495,-0.000026423314989432287,-0.00002730553614066766,-0.000028165729516477008,-0.00002900389511686032,-0.0000298200329 ...

# %% [markdown]
# Ahora calculamos la tasa de acreción y la masa todal acretada

# %%
import plotly.graph_objects as go
import numpy as np

# Calculate accretion rate and total accreted mass
accretion_rate, total_mass = analyzer.calculate_accretion()
# Calcular el promedio de la tasa de acreción
avg_accretion_rate = np.mean(accretion_rate)



# Crear la figura con Plotly
fig = go.Figure()

# Agregar la línea de la tasa de acreción
fig.add_trace(go.Scatter(
    x=analyzer.time,
    y=accretion_rate,
    mode='lines',
    name='Accretion Rate',
    line=dict(color='dodgerblue', width=2)
))

# Agregar la línea promedio
fig.add_trace(go.Scatter(
    x=analyzer.time,
    y=[avg_accretion_rate] * len(analyzer.time),
    mode='lines',
    name=f'Avg: {avg_accretion_rate:.2e} Msun/yr',
    line=dict(color='orangered', width=2, dash='dash')
))


fig.update_layout(
    title="Accretion Rate Over Time",
    xaxis_title="Normalized Time",
    yaxis_title="Accretion Rate [Msun/yr]",
    template="plotly_white",
    font=dict(size=14),
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True, exponentformat="e"),
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="163ae067-a41a-44bb-9c00-6657765ff663" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("163ae067-a41a-44bb-9c00-6657765ff663")) {                    Plotly.newPlot(                        "163ae067-a41a-44bb-9c00-6657765ff663",                        [{"line":{"color":"dodgerblue","width":2},"mode":"lines","name":"Accretion Rate","x":[0.0,0.010101010101010102,0.020202020202020204,0.030303030303030304,0.04040404040404041,0.05050505050505051,0.06060606060606061,0.07070707070707072,0.08080808080808081,0.09090909090909091,0.10101010101010102,0.11111111111111112,0.12121212121212122,0.13131313131313133,0.14141414141414144,0.15151515151515152,0.16161616161616163,0.17171717171717174,0.18181818181818182,0.19191919191919193,0.20202020202020204,0.21212121212121213,0.22222222222222224,0.23232323232323235,0.24242424242424243,0.25252525252525254,0.26262626262626265,0.27272727272727276,0.2828282828282829,0.29292929292929293,0.30303030303030304,0.31313131313131315,0.32323232323232326,0.33333333333333337,0.3434343434343435,0.3535353535353536,0.36363636363636365,0.37373737373737376,0.38383838383838387,0.393939393939394,0.4040404040404041,0.4141414141414142,0.42424242424242425,0.43434343434343436,0.4444444444444445,0.4545454545454546,0.4646464646464647,0.4747474747474748,0.48484848484848486,0.494949494949495,0.5050505050505051,0.5151515151515152,0.5252525252525253,0.5353535353535354,0.5454545454545455,0.5555555555555556,0.5656565656565657,0.5757575757575758,0.5858585858585859,0.595959595959596,0.6060606060606061,0.6161616161616162,0.6262626262626263,0.6363636363636365,0.6464646464646465,0.6565656565656566,0.6666666666666667,0.6767676767676768,0.686868686868687,0.696969696969697,0.7070707070707072,0.7171717171717172,0.7272727272727273,0.7373737373737375,0.7474747474747475,0.7575757575757577,0.7676767676767677,0.7777777777777778,0.787878787878788,0.797979797979798,0.8080808080808082,0.8181818181818182,0.8282828282828284,0.8383838383838385,0.8484848484848485,0.8585858585858587,0.8686868686868687,0.8787878787878789,0.888888888888889,0.8989898989898991,0.9090909090909092,0.9191919191919192,0.9292929292929294,0.9393939393939394,0.9494949494949496,0.9595959595959597,0.9696969696969697,0.9797979797979799,0.98989898989899,1.0],"y":[-0.00015997149825673073,-0.00015997149825673342,-0.00015997149825673477,-0.00015997149825673342,-0.00015997149825673342,-0.00015997149825673342,-0.00015997149825673342,-0.00015997149825673342,-0.00015997149825673342,-0.00015997149825673342,-0.00015997149825673342,-0.00006953447088396664,0.0000209025564887988,0.00002090255648880014,0.0000209025564887988,0.000020902556488796115,0.0000209025564887988,0.00002090255648880014,0.0000209025564887988,0.0000209025564887988,0.0000209025564887988,0.0000209025564887988,7.023828739564681e-6,-6.854899009669437e-6,-6.854899009668093e-6,-6.854899009668093e-6,-6.854899009670779e-6,-6.854899009669437e-6,-6.85489900966675e-6,-6.854899009668093e-6,-6.854899009669437e-6,-6.854899009669437e-6,-6.854899009668093e-6,-0.0001336107075264553,-0.0002603665160432398,-0.0002603665160432371,-0.0002603665160432398,-0.0002603665160432425,-0.00026036651604324117,-0.0002603665160432398,-0.00026036651604323846,-0.00026036651604323846,-0.0002603665160432398,-0.0002603665160432398,-0.00024452407835607725,-0.000228681640668916,-0.00022868164066891468,-0.00022868164066891332,-0.000228681640668916,-0.000228681640668916,-0.00022868164066891468,-0.00022868164066891332,-0.00022868164066891332,-0.000228681640668916,-0.000228681640668916,-0.00018631325486748325,-0.00014394486906605321,-0.00014394486906605457,-0.00014394486906605321,-0.00014394486906605321,-0.00014394486906605457,-0.00014394486906605321,-0.00014394486 ...

# %%
print(f"Total Accreted Mass: {total_mass:.2e} Msun")
# Out:
# Total Accreted Mass: -1.73e-05 Msun
